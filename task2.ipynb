# %%
import pandas as pd

# %%
df = pd.read_csv("WineQT.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df=pd.read_csv("WineQT.csv")
df[df['alcohol'] > 12]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 32              4.6              0.52         0.15             2.1      0.054
# 91              5.6              0.50         0.09             2.3      0.049
# 96              5.2              0.34         0.00             1.8      0.050
# 98              5.2              0.34         0.00             1.8      0.050
# 148             9.7              0.53         0.60             2.0      0.039
# ...             ...               ...          ...             ...        ...
# 1052            5.3              0.47         0.11             2.2      0.048
# 1054            5.3              0.47         0.11             2.2      0.048
# 1064            7.1              0.22         0.49             1.8      0.039
# 1122            6.4              0.36         0.53             2.2      0.230
# 1125            6.0              0.58         0.20             2.4      0.075
#
# ...

# %%
df=pd.read_csv("WineQT.csv")
df[df['quality'] >= 7]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 12              8.5              0.28         0.56             1.8      0.092
# 27              8.1              0.38         0.28             2.1      0.066
# 89              8.0              0.59         0.16             1.8      0.065
# ...             ...               ...          ...             ...        ...
# 1096            6.6              0.56         0.14             2.4      0.064
# 1100            8.4              0.37         0.43             2.3      0.063
# 1104            7.4              0.36         0.30             1.8      0.074
# 1108            7.0              0.56         0.17             1.7      0.065
# 1133            6.7              0.32         0.44             2.4      0.061
#
# ...

# %%
import pandas  as pd

# %%
df=pd.read_csv("WineQT.csv")
df[df['pH'] > 3.0]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df=pd.read_csv("WineQT.csv")
df[(df['fixed acidity'] >= 8.0) & (df['fixed acidity'] <= 10.0)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 12              8.5             0.280         0.56             1.8      0.092
# 16              8.5             0.490         0.11             2.3      0.084
# 23              8.3             0.655         0.12             2.3      0.083
# 27              8.1             0.380         0.28             2.1      0.066
# 29              8.8             0.610         0.30             2.8      0.088
# ...             ...               ...          ...             ...        ...
# 1058            8.2             0.280         0.60             3.0      0.104
# 1059            8.1             0.330         0.44             1.5      0.042
# 1095            8.0             0.390         0.30             1.9      0.074
# 1100            8.4             0.370         0.43             2.3      0.063
# 1127            8.0             0.300         0.63             1.6      0.081
#
# ...

# %%
df=pd.read_csv("WineQT.csv")
df[df['residual sugar'] > 5.0]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 25              7.8             0.645         0.00             5.5      0.086
# 28              7.3             0.450         0.36             5.9      0.074
# 106             7.1             0.430         0.42             5.5      0.071
# 107             7.1             0.430         0.42             5.5      0.070
# 108             7.1             0.430         0.42             5.5      0.071
# ...             ...               ...          ...             ...        ...
# 1051            9.9             0.500         0.50            13.8      0.205
# 1053            9.9             0.500         0.50            13.8      0.205
# 1055            7.1             0.875         0.05             5.7      0.082
# 1111            6.9             0.630         0.33             6.7      0.235
# 1128            6.2             0.700         0.15             5.1      0.076
#
# ...

# %%
df=pd.read_csv("WineQT.csv")
df[df['chlorides'] == 0.075]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# 85              7.3             0.695         0.00             2.5      0.075
# 170            15.0             0.210         0.44             2.2      0.075
# 171            15.0             0.210         0.44             2.2      0.075
# 173             7.1             0.680         0.07             1.9      0.075
# 180             9.4             0.340         0.37             2.2      0.075
# 181             6.6             0.695         0.00             2.1      0.075
# 281             7.7             0.690         0.05             2.7      0.075
# 337            10.4             0.240         0.49             1.8      0.075
# 359            10.4             0.240         0.46             1.8      0.075
# ...

# %%
df[df['density']>0.998]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 14              7.6             0.390         0.31             2.3      0.082
# 25              7.8             0.645         0.00             5.5      0.086
# 51              8.8             0.410         0.64             2.2      0.093
# 79             10.1             0.310         0.44             2.3      0.080
# 103             9.2             0.520         1.00             3.4      0.610
# ...             ...               ...          ...             ...        ...
# 1056            8.2             0.280         0.60             3.0      0.104
# 1058            8.2             0.280         0.60             3.0      0.104
# 1077            7.1             0.270         0.60             2.1      0.074
# 1081            6.9             0.840         0.21             4.1      0.074
# 1082            6.9             0.840         0.21             4.1      0.074
#
# ...

# %%
filtered_df = df[
    (df['alcohol'] < 9.5) & 
    (df['quality'] == 5)
]

# %%
first_50_rows=df.iloc[:50]
first_50_rows
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00            1.90      0.076
# 1             7.8             0.880         0.00            2.60      0.098
# 2             7.8             0.760         0.04            2.30      0.092
# 3            11.2             0.280         0.56            1.90      0.075
# 4             7.4             0.700         0.00            1.90      0.076
# 5             7.4             0.660         0.00            1.80      0.075
# 6             7.9             0.600         0.06            1.60      0.069
# 7             7.3             0.650         0.00            1.20      0.065
# 8             7.8             0.580         0.02            2.00      0.073
# 9             6.7             0.580         0.08            1.80      0.097
# 10            5.6             0.615         0.00            1.60      0.089
# ...

# %%
extract_df = df[df['quality'] == 8][['pH', 'alcohol']]

# %%
df['volatile acidity'].max()
# Out:
# np.float64(1.58)

# %%
filtered_df = df[df['citric acid'] == 0]
filtered_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700          0.0             1.9      0.076
# 1               7.8             0.880          0.0             2.6      0.098
# 4               7.4             0.700          0.0             1.9      0.076
# 5               7.4             0.660          0.0             1.8      0.075
# 7               7.3             0.650          0.0             1.2      0.065
# ...             ...               ...          ...             ...        ...
# 1029            6.8             0.670          0.0             1.9      0.080
# 1035            6.5             0.900          0.0             1.6      0.052
# 1040            6.2             0.785          0.0             2.1      0.060
# 1105            7.1             0.670          0.0             2.3      0.083
# 1107            7.3             0.735          0.0             2.2      0.080
#
# ...

# %%
filtered_df = df[df['sulphates'] > 10]
filtered_df
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality, Id]
# Index: []

# %%
df['quality_label'] = df['quality'].transform(lambda x: 'Good' if x > 7 else 'Bad')
filtered_df = df[df['quality_label'] == 'Good']
filtered_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 190             7.9              0.35         0.46             3.6      0.078
# 197            10.3              0.32         0.45             6.4      0.073
# 271             5.6              0.85         0.05             1.4      0.045
# 310            12.6              0.31         0.72             2.2      0.072
# 321            11.3              0.62         0.67             5.2      0.086
# 340             9.4              0.30         0.56             2.8      0.080
# 349            10.7              0.35         0.53             2.6      0.070
# 352            10.7              0.35         0.53             2.6      0.070
# 419             5.0              0.42         0.24             2.0      0.060
# 747             9.1              0.40         0.50             1.8      0.071
# 769            10.0              0.26         0.54             1.9      0.083
# ...

# %%
filtered_df=df[df['total sulfur dioxide']>2*df['free sulfur dioxide']]
filtered_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1125            6.0             0.580         0.20             2.4      0.075
# 1128            6.2             0.700         0.15             5.1      0.076
# 1130            7.4             0.350         0.33             2.4      0.068
# 1131            6.1             0.715         0.10             2.6      0.053
# 1132            6.2             0.460         0.29             2.1      0.074
#
# ...

# %%
selected_row=df.iloc[100:201,:3]
filtered_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1125            6.0             0.580         0.20             2.4      0.075
# 1128            6.2             0.700         0.15             5.1      0.076
# 1130            7.4             0.350         0.33             2.4      0.068
# 1131            6.1             0.715         0.10             2.6      0.053
# 1132            6.2             0.460         0.29             2.1      0.074
#
# ...

# %%
filtered_df=df[df['alcohol']> df['alcohol'].mean()]
filtered_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 12              8.5              0.28         0.56             1.8      0.092
# 26              7.8              0.60         0.14             2.4      0.086
# 28              7.3              0.45         0.36             5.9      0.074
# 30              7.5              0.49         0.20             2.6      0.332
# 32              4.6              0.52         0.15             2.1      0.054
# ...             ...               ...          ...             ...        ...
# 1136            6.3              0.55         0.15             1.8      0.077
# 1137            5.4              0.74         0.09             1.7      0.089
# 1138            6.3              0.51         0.13             2.3      0.076
# 1140            6.2              0.60         0.08             2.0      0.090
# 1141            5.9              0.55         0.10             2.2      0.062
#
# ...

# %%
filtered_df = df[(df['fixed acidity'] > 12) | (df['volatile acidity'] > 1.0)]
filtered_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 66              5.0             1.020         0.04             1.4      0.045
# 83              7.3             1.070         0.09             1.7      0.178
# 87              8.2             1.330         0.00             1.7      0.081
# 88              8.1             1.330         0.00             1.8      0.082
# 92              7.9             1.040         0.05             2.2      0.084
# 142             6.9             1.090         0.06             2.1      0.061
# 145            12.8             0.300         0.74             2.6      0.095
# 146            12.8             0.300         0.74             2.6      0.095
# 170            15.0             0.210         0.44             2.2      0.075
# 171            15.0             0.210         0.44             2.2      0.075
# 188            12.5             0.560         0.49             2.4      0.064
# ...

# %%
filtered_df = df[df['chlorides'] <= df['chlorides'].quantile(0.10)]
filtered_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 32              4.6             0.520         0.15             2.1      0.054
# 66              5.0             1.020         0.04             1.4      0.045
# 91              5.6             0.500         0.09             2.3      0.049
# 96              5.2             0.340         0.00             1.8      0.050
# 98              5.2             0.340         0.00             1.8      0.050
# ...             ...               ...          ...             ...        ...
# 1118            6.7             0.160         0.64             2.1      0.059
# 1121            6.2             0.510         0.14             1.9      0.056
# 1123            6.4             0.380         0.14             2.2      0.038
# 1126            7.5             0.520         0.40             2.2      0.060
# 1131            6.1             0.715         0.10             2.6      0.053
#
# ...

# %%
filtered_df = df[
    (df['pH'].between(3.2, 3.4)) & 
    (df['density'] < 0.995)
]
filtered_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 7               7.3              0.65         0.00             1.2      0.065
# 238             8.9              0.43         0.45             1.9      0.052
# 249             6.1              0.21         0.40             1.4      0.066
# 329             8.8              0.46         0.45             2.6      0.065
# 580             8.4              0.25         0.39             2.0      0.041
# ...             ...               ...          ...             ...        ...
# 1126            7.5              0.52         0.40             2.2      0.060
# 1130            7.4              0.35         0.33             2.4      0.068
# 1133            6.7              0.32         0.44             2.4      0.061
# 1134            7.5              0.31         0.41             2.4      0.065
# 1136            6.3              0.55         0.15             1.8      0.077
#
# ...

# %%
df[df['residual sugar']%2==0]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 8               7.8             0.580         0.02             2.0      0.073
# 21              7.8             0.645         0.00             2.0      0.082
# 44              7.0             0.735         0.05             2.0      0.081
# 53              6.7             0.750         0.12             2.0      0.086
# 56              7.4             0.500         0.47             2.0      0.086
# ...             ...               ...          ...             ...        ...
# 1115            7.2             0.695         0.13             2.0      0.076
# 1116            7.2             0.695         0.13             2.0      0.076
# 1119            7.2             0.695         0.13             2.0      0.076
# 1140            6.2             0.600         0.08             2.0      0.090
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
top_10_wines=df.nlargest(10,'alcohol')
top_10_wines
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 462           15.9              0.36         0.65             7.5      0.096
# 96             5.2              0.34         0.00             1.8      0.050
# 98             5.2              0.34         0.00             1.8      0.050
# 329            8.8              0.46         0.45             2.6      0.065
# 419            5.0              0.42         0.24             2.0      0.060
# 589            4.9              0.42         0.00             2.1      0.048
# 898            5.0              0.38         0.01             1.6      0.048
# 787            5.0              0.40         0.50             4.3      0.046
# 799            7.4              0.36         0.34             1.8      0.075
# 868            5.1              0.42         0.00             1.8      0.044
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
filtered_df=df[
    (df['quality']!=5)|
    (df['quality']!=6)
    ]
filtered_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df[df["citric acid"]>df["volatile acidity"]]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 12              8.5              0.28         0.56             1.8      0.092
# 13              7.9              0.32         0.51             1.8      0.341
# 39             10.2              0.42         0.57             3.4      0.070
# 51              8.8              0.41         0.64             2.2      0.093
# ...             ...               ...          ...             ...        ...
# 1118            6.7              0.16         0.64             2.1      0.059
# 1122            6.4              0.36         0.53             2.2      0.230
# 1127            8.0              0.30         0.63             1.6      0.081
# 1133            6.7              0.32         0.44             2.4      0.061
# 1134            7.5              0.31         0.41             2.4      0.065
#
# ...
